# %% [markdown]
# # Your Use Case
#
#
# You work at a e-commerce company  selling online groceries and other home goods.
#
# The company:
#
# - operates in your country
# - you have a similar role to your current one (or your dream role)
# - wants to create a beautiful experience
# - cares about retention, trust and therefore privacy
# - works in an agile fashion and has several product, software and data teams
#
#
#
# There will be a variety of code and non-coding challenges. If you are coding, please install the repository:
#
# `kjam/practical-data-privacy`

# %%
# !pip install Faker
# Out:
# Requirement already satisfied: Faker in /opt/miniconda3/envs/book/lib/python3.12/site-packages (26.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/miniconda3/envs/book/lib/python3.12/site-packages (from Faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/book/lib/python3.12/site-packages (from python-dateutil>=2.4->Faker) (1.16.0)

# %%
from faker import Faker
from pprint import pprint
import json
import random
from collections import Counter


fake = Faker('en_US') #change locale if you'd like!

# %%
USER_MEMBERSHIP_NUMBERS = range(5000)

# loosely adapted from https://www.ziplist.com/grocery-list-template/categories
CATEGORIES_AND_ITEMS = {
    "Fruits": ["bananas", "apples", "grapes", "oranges", "strawberries", "avocados", "peaches", "pineapple", "pears"],
    "Vegetables": ["potatoes", "tomatoes", "onions", "carrots", "lettuce", "broccoli", "peppers", "celery", "garlic", "cucumbers"],
    "Canned Goods": ["olives", "soup", "canned tuna", "veggies", "fruit"],
    "Frozen Foods": ["fish", "ice cream", "pizza", "frozen potatoes", "ready meals"],
    "Meat and Animal Products": ["chicken", "beef", "pork", "sausage", "eggs"],
    "Vegetarian and Vegan Alternatives": ["veggie burgers", "tofu", "vegan fish", "oat milk", "vegan sausages"],
    "Fish and shellfish": ["shrimp", "crab", "clams", "tuna", "salmon", "tilapia"],
    "Dairy": ["cheese", "milk", "yogurt", "butter"],
    "Deli": ["sliced cheese", "ham", "turkey", "salami"],
    "Condiments & Spices": ["salt", "sugar", "pepper", "oregano", "cinnamon", "ketchup", "mayonnaise", "mustard"],
    "Sauces & Oils": ["olive oil", "tomato sauce", "hot sauce", "soy sauce"],
    "Snacks": ["chips", "crackers", "pretzels", "popcorn", "peanuts", "nuts", "candy"],
    "Bread & Bakery": ["whole wheat", "white", "italian", "sandwich", "tortillas", "pies", "muffins", "bagels", "cookies"],
    "Beverages": ["water", "coffee", "juice", "soda", "tea", "beer", "wine"],
    "Pasta/Rice": ["spaghetti", "macaroni", "noodles", "white rice"],
    "Cereal": ["oats", "rice", "wheat", "granola"],
    "Baking": ["flour", "baking powder", "sprinkles"],
    "Personal Care": ["shampoo", "conditioner", "soap", "deodorant", "toothpaste", "dental floss", "shaving cream", "razor blades"],
    "Health Care": ["band-aid", "hydrogen peroxide", "rubbing alcohol", "pain reliever", "antacids"],
    "Paper & Wrap": ["toilet paper", "paper towels", "tissues", "aluminum foil", "zip bags"],
    "Household Supplies": ["detergent", "softener", "bleach", "dish soap", "air freshener", "gloves", "sponge", "trash bags", "batteries"],
    "Baby Items": ["baby food", "diapers", "wet wipes", "moisturizing lotion"],
    "Other items": ["pet food", "flowers", "tobacco"],
}

CATEGORIES_WITH_WEIGHTS = [
    ("Fruits", 10),
    ("Vegetables", 10),
    ("Canned Goods", 4),
    ("Frozen Foods", 5),
    ("Meat and Animal Products", 5),
    ("Vegetarian and Vegan Alternatives", 5),
    ("Fish and shellfish", 5),
    ("Dairy", 5),
    ("Deli", 3),
    ("Condiments & Spices", 3),
    ("Sauces & Oils", 3),
    ("Snacks", 5),
    ("Bread & Bakery", 5),
    ("Beverages", 5),
    ("Pasta/Rice", 7),
    ("Cereal", 3),
    ("Baking", 3),
    ("Personal Care", 4),
    ("Health Care", 2),
    ("Paper & Wrap", 2),
    ("Household Supplies", 3),
    ("Baby Items", 2),
    ("Other items", 1),
]

STORE_LOCATIONS = ["{}, {}".format(fake.unique.city(), fake.state()) for _ in range(30)]

STORE_DICT = dict([(loc, fake.unique.random_int(min=1000, max=9999)) for loc in STORE_LOCATIONS])

CATEGORIES_AND_ITEMS.values()

def flatten(lols):
    return [item for sublist in lols for item in sublist]

ITEM_LOOKUP = dict([(item_name, fake.unique.random_int(min=10000, max=99999)) for item_name in flatten(CATEGORIES_AND_ITEMS.values())])

# %%
print(sum(w for _, w in CATEGORIES_WITH_WEIGHTS))
sum(w for _, w in CATEGORIES_WITH_WEIGHTS) == 100
# Out:
# 100
# True

# %%
most_common, num_most_common = Counter(STORE_DICT.values()).most_common(1)[0]
num_most_common == 1
# Out:
# True

# %%
most_common, num_most_common = Counter(ITEM_LOOKUP.values()).most_common(1)[0]
num_most_common == 1
# Out:
# True

# %%
def generate_items(CATEGORIES_AND_ITEMS, with_quantity=False):
    category = random.choices([c for c,_ in CATEGORIES_WITH_WEIGHTS], 
                              [w for _,w in CATEGORIES_WITH_WEIGHTS], k=1)[0]
    item = random.choice(CATEGORIES_AND_ITEMS[category])
    return {"category": category, 
            "item": item, 
            "item_id": ITEM_LOOKUP[item],
            "quantity": random.choices([1, 2, 3, 4], [30, 30, 20, 10], k=1)[0]}

# %%
# generate row
SALES_DATASET = []

for i in range(50000):
    location = random.choice(STORE_LOCATIONS)
    SALES_DATASET.append({
        "membership_number": (lambda n: str(random.choice(USER_MEMBERSHIP_NUMBERS)) if n <= 0.5 else "")(random.random()),
        "sale_datetime": fake.date_time().isoformat(),
        "sale_id": 3000 + i,
        "items": [generate_items(CATEGORIES_AND_ITEMS) for _ in range(random.randrange(3, 30, 1))],
        "store_location": location,
        "store_id": STORE_DICT[location]
    })

# %%
for sale in SALES_DATASET[:5]:
    pprint(sale)
# Out:
# {'items': [{'category': 'Fish and shellfish',
#             'item': 'salmon',
#             'item_id': 41258,
#             'quantity': 1},
#            {'category': 'Fruits',
#             'item': 'avocados',
#             'item_id': 44717,
#             'quantity': 2},
#            {'category': 'Health Care',
#             'item': 'hydrogen peroxide',
#             'item_id': 53586,
#             'quantity': 3},
#            {'category': 'Snacks',
#             'item': 'nuts',
#             'item_id': 20537,
#             'quantity': 1},
#            {'category': 'Condiments & Spices',
#             'item': 'mustard',
#             'item_id': 39739,
#             'quantity': 3},
#            {'category': 'Frozen Foods',
#             'item': 'ready meals',
#             'item_id': 70579,
#             'quantity': 2},
#            {'category': 'Deli', 'item': 'ham', 'item_id': 67720, 'quantity': 2},
#            {'category': 'Frozen Foods',
#             'item': 'ready meals',
#             'item_id': 70579,
#             'quantity': 1},
#            {'category': 'Fruits',
#             'item': 'oranges',
#             'item_id': 39399,
#             'quantity': 4},
#            {'category': 'Canned Goods',
#             'item': 'olives',
#             'item_id': 63588,
#             'quantity': 4},
#            {'category': 'Vegetables',
#             'item': 'carrots',
#             'item_id': 22481,
#             'quantity': 2},
#            {'category': 'Cereal',
#             'item': 'wheat',
#             'item_id': 23802,
#             'quantity': 2},
#            {'category': 'Paper & Wrap',
#             'item': 'aluminum foil',
#             'item_id': 45492,
#             'quantity': 3},
#            {'category': 'Pasta/Rice',
#             'item': 'spaghetti',
#             'item_id': 14783,
#             'quantity': 1},
#            {'category': 'Vegetarian and Vegan Alternatives',
#             'item': 'tofu',
#             'item_id': 95130,
#             'quantity': 1},
#            {'category': 'Health Care',
#             'item': 'pain reliever',
#             'item_id': 91276,
#             'quantity': 3},
#            {'category': 'Vegetables',
#             'item': 'potatoes',
#             'item_id': 89599,
#             'quantity': 2}],
#  'membership_number': '',
#  'sale_datetime': '1990-03-04T03:53:32.827930',
#  'sale_id': 3000,
#  'store_id': 4690,
#  'store_location': 'Lake Justinmouth, Iowa'}
# {'items': [{'category': 'Pasta/Rice',
#             'item': 'spaghetti',
#             'item_id': 14783,
#             'quantity': 1},
#            {'category': 'Fish and shellfish',
#             'item': 'crab',
#             'item_id': 92164,
#             'quantity': 1},
#            {'category': 'Personal Care',
#             'item': 'shampoo',
#             'item_id': 33964,
#             'quantity': 2},
#            {'category': 'Meat and Animal Products',
#             'item': 'chicken',
#             'item_id': 33590,
#             'quantity': 2},
#            {'category': 'Bread & Bakery',
#             'item': 'italian',
#             'item_id': 72139,
#             'quantity': 3},
#            {'category': 'Condiments & Spices',
#             'item': 'pepper',
#             'item_id': 72867,
#             'quantity': 3},
#            {'category': 'Vegetables',
#             'item': 'celery',
#             'item_id': 49761,
#             'quantity': 2},
#            {'category': 'Fruits',
#             'item': 'pears',
#             'item_id': 99461,
#             'quantity': 1},
#            {'category': 'Meat and Animal Products',
#             'item': 'beef',
#             'item_id': 94762,
#             'quantity': 3},
#            {'category': 'Health Care',
#             'item': 'pain reliever',
#             'item_id': 91276,
#             'quantity': 1},
#            {'category': 'Household Supplies',
#             'item': 'dish soap',
#             'item_id': 21681,
#             'quantity': 3}],
#  'membership_number': '856',
#  'sale_datetime': '1980-12-29T22:11:03.993086',
#  'sale_id': 3001,
#  'store_id': 6025,
#  'store_location': 'Rachaelchester, Georgia'}
# {'items': [{'category': 'Cereal',
#             'item': 'wheat',
#             'item_id': 23802,
#             'quantity': 1},
#            {'category': 'Vegetables',
#             'item': 'carrots',
#             'item_id': 22481,
#             'quantity': 1},
#            {'category': 'Other items',
#             'item': 'flowers',
#             'item_id': 33171,
#             'quantity': 2},
#            {'category': 'Health Care',
#             'item': 'band-aid',
#             'item_id': 89842,
#             'quantity': 1},
#            {'category': 'Bread & Bakery',
#             'item': 'tortillas',
#             'item_id': 16948,
#             'quantity': 1},
#            {'category': 'Bread & Bakery',
#             'item': 'sandwich',
#             'item_id': 33242,
#             'quantity': 2},
#            {'category': 'Fish and shellfish',
#             'item': 'crab',
#             'item_id': 92164,
#             'quantity': 1},
#            {'category': 'Vegetables',
#             'item': 'tomatoes',
#             'item_id': 75330,
#             'quantity': 4},
#            {'category': 'Bread & Bakery',
#             'item': 'white',
#             'item_id': 39679,
#             'quantity': 2},
#            {'category': 'Vegetables',
#             'item': 'peppers',
#             'item_id': 26725,
#             'quantity': 4},
#            {'category': 'Baby Items',
#             'item': 'wet wipes',
#             'item_id': 10801,
#             'quantity': 1},
#            {'category': 'Bread & Bakery',
#             'item': 'italian',
#             'item_id': 72139,
#             'quantity': 1},
#            {'category': 'Fruits',
#             'item': 'grapes',
#             'item_id': 78138,
#             'quantity': 3},
#            {'category': 'Personal Care',
#             'item': 'razor blades',
#             'item_id': 66995,
#             'quantity': 1},
#            {'category': 'Vegetables',
#             'item': 'broccoli',
#             'item_id': 48349,
#             'quantity': 3},
#            {'category': 'Beverages',
#             'item': 'coffee',
#             'item_id': 93141,
#             'quantity': 1},
#            {'category': 'Frozen Foods',
#             'item': 'fish',
#             'item_id': 37256,
#             'quantity': 1},
#            {'category': 'Sauces & Oils',
#             'item': 'olive oil',
#             'item_id': 97881,
#             'quantity': 1},
#            {'category': 'Household Supplies',
#             'item': 'bleach',
#             'item_id': 26682,
#             'quantity': 3}],
#  'membership_number': '',
#  'sale_datetime': '1978-12-15T19:00:46.125968',
#  'sale_id': 3002,
#  'store_id': 8952,
#  'store_location': 'Lake Steven, Utah'}
# {'items': [{'category': 'Baby Items',
#             'item': 'wet wipes',
#             'item_id': 10801,
#             'quantity': 2},
#            {'category': 'Cereal',
#             'item': 'wheat',
#             'item_id': 23802,
#             'quantity': 3},
#            {'category': 'Bread & Bakery',
#             'item': 'tortillas',
#             'item_id': 16948,
#             'quantity': 2},
#            {'category': 'Snacks',
#             'item': 'candy',
#             'item_id': 71183,
#             'quantity': 2},
#            {'category': 'Fruits',
#             'item': 'peaches',
#             'item_id': 28815,
#             'quantity': 2},
#            {'category': 'Vegetarian and Vegan Alternatives',
#             'item': 'vegan fish',
#             'item_id': 84978,
#             'quantity': 2}],
#  'membership_number': '2233',
#  'sale_datetime': '2005-07-03T03:11:09.251183',
#  'sale_id': 3003,
#  'store_id': 8040,
#  'store_location': 'New Randall, Massachusetts'}
# {'items': [{'category': 'Health Care',
#             'item': 'antacids',
#             'item_id': 29034,
#             'quantity': 2},
#            {'category': 'Vegetables',
#             'item': 'lettuce',
#             'item_id': 40631,
#             'quantity': 2},
#            {'category': 'Fish and shellfish',
#             'item': 'shrimp',
#             'item_id': 61764,
#             'quantity': 3},
#            {'category': 'Pasta/Rice',
#             'item': 'white rice',
#             'item_id': 44001,
#             'quantity': 3},
#            {'category': 'Snacks',
#             'item': 'crackers',
#             'item_id': 24109,
#             'quantity': 1},
#            {'category': 'Household Supplies',
#             'item': 'detergent',
#             'item_id': 38077,
#             'quantity': 2},
#            {'category': 'Sauces & Oils',
#             'item': 'soy sauce',
#             'item_id': 54082,
#             'quantity': 1},
#            {'category': 'Deli',
#             'item': 'salami',
#             'item_id': 16905,
#             'quantity': 2},
#            {'category': 'Beverages',
#             'item': 'soda',
#             'item_id': 69764,
#             'quantity': 3},
#            {'category': 'Pasta/Rice',
#             'item': 'white rice',
#             'item_id': 44001,
#             'quantity': 1},
#            {'category': 'Canned Goods',
#             'item': 'olives',
#             'item_id': 63588,
#             'quantity': 2},
#            {'category': 'Frozen Foods',
#             'item': 'pizza',
#             'item_id': 77761,
#             'quantity': 2},
#            {'category': 'Fish and shellfish',
#             'item': 'tilapia',
#             'item_id': 35531,
#             'quantity': 2},
#            {'category': 'Deli', 'item': 'ham', 'item_id': 67720, 'quantity': 1},
#            {'category': 'Fruits',
#             'item': 'avocados',
#             'item_id': 44717,
#             'quantity': 2},
#            {'category': 'Bread & Bakery',
#             'item': 'cookies',
#             'item_id': 84395,
#             'quantity': 1},
#            {'category': 'Condiments & Spices',
#             'item': 'salt',
#             'item_id': 31814,
#             'quantity': 2},
#            {'category': 'Household Supplies',
#             'item': 'detergent',
#             'item_id': 38077,
#             'quantity': 1}],
#  'membership_number': '',
#  'sale_datetime': '1992-09-12T12:53:49.083516',
#  'sale_id': 3004,
#  'store_id': 1007,
#  'store_location': 'Robinsonchester, Utah'}

# %%
with open('data/sales.json', 'w', encoding='utf-8') as f:
    json.dump(SALES_DATASET, f, indent=4)

# %%
# !head -n 50 data/sales.json
# Out:
# [
#     {
#         "membership_number": "",
#         "sale_datetime": "1990-03-04T03:53:32.827930",
#         "sale_id": 3000,
#         "items": [
#             {
#                 "category": "Fish and shellfish",
#                 "item": "salmon",
#                 "item_id": 41258,
#                 "quantity": 1
#             },
#             {
#                 "category": "Fruits",
#                 "item": "avocados",
#                 "item_id": 44717,
#                 "quantity": 2
#             },
#             {
#                 "category": "Health Care",
#                 "item": "hydrogen peroxide",
#                 "item_id": 53586,
#                 "quantity": 3
#             },
#             {
#                 "category": "Snacks",
#                 "item": "nuts",
#                 "item_id": 20537,
#                 "quantity": 1
#             },
#             {
#                 "category": "Condiments & Spices",
#                 "item": "mustard",
#                 "item_id": 39739,
#                 "quantity": 3
#             },
#             {
#                 "category": "Frozen Foods",
#                 "item": "ready meals",
#                 "item_id": 70579,
#                 "quantity": 2
#             },
#             {
#                 "category": "Deli",
#                 "item": "ham",
#                 "item_id": 67720,
#                 "quantity": 2
#             },
#             {
#                 "category": "Frozen Foods",

# %%
LIST_DATASET = []

STORE_SAMPLE = random.sample(list(STORE_DICT.values()), 3)

for i in range(5):
    LIST_DATASET.append({
        "list_items": [generate_items(CATEGORIES_AND_ITEMS) for _ in range(random.randrange(3, 30, 1))],
        "store_location_preferences": random.sample(STORE_SAMPLE, 2), 
    })

# %%
LIST_DATASET
# Out:
# [{'list_items': [{'category': 'Frozen Foods',
#     'item': 'ready meals',
#     'item_id': 70579,
#     'quantity': 1},
#    {'category': 'Frozen Foods',
#     'item': 'fish',
#     'item_id': 37256,
#     'quantity': 2},
#    {'category': 'Fish and shellfish',
#     'item': 'salmon',
#     'item_id': 41258,
#     'quantity': 2},
#    {'category': 'Pasta/Rice',
#     'item': 'white rice',
#     'item_id': 44001,
#     'quantity': 3},
#    {'category': 'Frozen Foods',
#     'item': 'frozen potatoes',
#     'item_id': 29709,
#     'quantity': 2},
#    {'category': 'Fish and shellfish',
#     'item': 'crab',
#     'item_id': 92164,
#     'quantity': 3},
#    {'category': 'Vegetables',
#     'item': 'peppers',
#     'item_id': 26725,
#     'quantity': 2},
#    {'category': 'Condiments & Spices',
#     'item': 'sugar',
#     'item_id': 43831,
#     'quantity': 2},
#    {'category': 'Fruits', 'item': 'bananas', 'item_id': 19917, 'quantity': 2},
#    {'category': 'Pasta/Rice',
#     'item': 'macaroni',
#     'item_id': 11656,
#     'quantity': 2},
#    {'category': 'Cereal', 'item': 'oats', 'item_id': 40982, 'quantity': 3},
#    {'category': 'Household Supplies',
#     'item': 'batteries',
#     'item_id': 43252,
#     'quantity': 3},
#    {'category': 'Vegetables',
#     'item': 'potatoes',
#     'item_id': 89599,
#     'quantity': 1},
#    {'category': 'Dairy', 'item': 'cheese', 'item_id': 67169, 'quantity': 1},
#    {'category': 'Bread & Bakery',
#     'item': 'whole wheat',
#     'item_id': 43893,
#     'quantity': 4},
#    {'category': 'Canned Goods',
#     'item': 'soup',
#     'item_id': 91321,
#     'quantity': 2},
#    {'category': 'Baby Items',
#     'item': 'wet wipes',
#     'item_id': 10801,
#     'quantity': 2},
#    {'category': 'Canned Goods',
#     'item': 'canned tuna',
#     'item_id': 92853,
#     'quantity': 1},
#    {'category': 'Health Care',
#     'item': 'rubbing alcohol',
#     'item_id': 28805,
#     'quantity': 2},
#    {'category': 'Cereal', 'item': 'rice', 'item_id': 99406, 'quantity': 2},
#    {'category': 'Fruits', 'item': 'avocados', 'item_id': 44717, 'quantity': 1},
#    {'category': 'Frozen Foods',
#     'item': 'fish',
#     'item_id': 37256,
#     'quantity': 3},
#    {'category': 'Personal Care',
#     'item': 'shaving cream',
#     'item_id': 64313,
#     'quantity': 3},
#    {'category': 'Fish and shellfish',
#     'item': 'tilapia',
#     'item_id': 35531,
#     'quantity': 3},
#    {'category': 'Vegetables',
#     'item': 'lettuce',
#     'item_id': 40631,
#     'quantity': 2}],
#   'store_location_preferences': [8040, 4936]},
#  {'list_items': [{'category': 'Deli',
#     'item': 'salami',
#     'item_id': 16905,
#     'quantity': 2},
#    {'category': 'Canned Goods',
#     'item': 'fruit',
#     'item_id': 43770,
#     'quantity': 3},
#    {'category': 'Health Care',
#     'item': 'antacids',
#     'item_id': 29034,
#     'quantity': 2},
#    {'category': 'Baby Items',
#     'item': 'diapers',
#     'item_id': 64434,
#     'quantity': 2}],
#   'store_location_preferences': [4936, 9916]},
#  {'list_items': [{'category': 'Vegetables',
#     'item': 'lettuce',
#     'item_id': 40631,
#     'quantity': 1},
#    {'category': 'Meat and Animal Products',
#     'item': 'eggs',
#     'item_id': 44613,
#     'quantity': 3},
#    {'category': 'Meat and Animal Products',
#     'item': 'pork',
#     'item_id': 61592,
#     'quantity': 2},
#    {'category': 'Fruits', 'item': 'bananas', 'item_id': 19917, 'quantity': 3},
#    {'category': 'Cereal', 'item': 'granola', 'item_id': 31738, 'quantity': 2},
#    {'category': 'Cereal', 'item': 'oats', 'item_id': 40982, 'quantity': 3},
#    {'category': 'Baby Items',
#     'item': 'moisturizing lotion',
#     'item_id': 67851,
#     'quantity': 4},
#    {'category': 'Deli',
#     'item': 'sliced cheese',
#     'item_id': 13557,
#     'quantity': 3},
#    {'category': 'Frozen Foods',
#     'item': 'fish',
#     'item_id': 37256,
#     'quantity': 1},
#    {'category': 'Baby Items',
#     'item': 'moisturizing lotion',
#     'item_id': 67851,
#     'quantity': 1},
#    {'category': 'Fruits', 'item': 'avocados', 'item_id': 44717, 'quantity': 2},
#    {'category': 'Fruits', 'item': 'oranges', 'item_id': 39399, 'quantity': 1},
#    {'category': 'Vegetarian and Vegan Alternatives',
#     'item': 'veggie burgers',
#     'item_id': 22280,
#     'quantity': 2},
#    {'category': 'Dairy', 'item': 'butter', 'item_id': 37032, 'quantity': 2},
#    {'category': 'Bread & Bakery',
#     'item': 'whole wheat',
#     'item_id': 43893,
#     'quantity': 1},
#    {'category': 'Fruits', 'item': 'peaches', 'item_id': 28815, 'quantity': 3},
#    {'category': 'Deli', 'item': 'salami', 'item_id': 16905, 'quantity': 1}],
#   'store_location_preferences': [9916, 4936]},
#  {'list_items': [{'category': 'Snacks',
#     'item': 'crackers',
#     'item_id': 24109,
#     'quantity': 2},
#    {'category': 'Meat and Animal Products',
#     'item': 'pork',
#     'item_id': 61592,
#     'quantity': 2},
#    {'category': 'Frozen Foods',
#     'item': 'frozen potatoes',
#     'item_id': 29709,
#     'quantity': 3},
#    {'category': 'Bread & Bakery',
#     'item': 'italian',
#     'item_id': 72139,
#     'quantity': 2},
#    {'category': 'Vegetables',
#     'item': 'lettuce',
#     'item_id': 40631,
#     'quantity': 2},
#    {'category': 'Frozen Foods',
#     'item': 'fish',
#     'item_id': 37256,
#     'quantity': 3},
#    {'category': 'Sauces & Oils',
#     'item': 'tomato sauce',
#     'item_id': 46457,
#     'quantity': 1}],
#   'store_location_preferences': [9916, 4936]},
#  {'list_items': [{'category': 'Pasta/Rice',
#     'item': 'macaroni',
#     'item_id': 11656,
#     'quantity': 2},
#    {'category': 'Fruits', 'item': 'peaches', 'item_id': 28815, 'quantity': 2},
#    {'category': 'Fish and shellfish',
#     'item': 'tuna',
#     'item_id': 49575,
#     'quantity': 2},
#    {'category': 'Snacks', 'item': 'peanuts', 'item_id': 63732, 'quantity': 3},
#    {'category': 'Condiments & Spices',
#     'item': 'sugar',
#     'item_id': 43831,
#     'quantity': 3},
#    {'category': 'Vegetables',
#     'item': 'lettuce',
#     'item_id': 40631,
#     'quantity': 1},
#    {'category': 'Personal Care',
#     'item': 'deodorant',
#     'item_id': 58973,
#     'quantity': 1},
#    {'category': 'Cereal', 'item': 'granola', 'item_id': 31738, 'quantity': 3},
#    {'category': 'Pasta/Rice',
#     'item': 'spaghetti',
#     'item_id': 14783,
#     'quantity': 3},
#    {'category': 'Vegetables',
#     'item': 'cucumbers',
#     'item_id': 53219,
#     'quantity': 1},
#    {'category': 'Other items',
#     'item': 'flowers',
#     'item_id': 33171,
#     'quantity': 1}],
#   'store_location_preferences': [4936, 8040]}]

# %%
with open('data/lists.json', 'w', encoding='utf-8') as f:
    json.dump(LIST_DATASET, f, indent=4)

# %%
INVENTORY_LIST = []

for location in STORE_SAMPLE:
    for cat, item_list in CATEGORIES_AND_ITEMS.items():
        INVENTORY_LIST.extend([{ 
            "category": cat, 
            "item": i,
            "item_id": ITEM_LOOKUP[i],
            "quantity": random.choices([1, 2, 3, 4], [30, 30, 20, 10], k=1)[0],
            "store_id": location,
        } for i in item_list])

# %%
INVENTORY_LIST
# Out:
# [{'category': 'Fruits',
#   'item': 'bananas',
#   'item_id': 19917,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'apples',
#   'item_id': 83260,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'grapes',
#   'item_id': 78138,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'oranges',
#   'item_id': 39399,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'strawberries',
#   'item_id': 85617,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'avocados',
#   'item_id': 44717,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'peaches',
#   'item_id': 28815,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'pineapple',
#   'item_id': 53555,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'pears',
#   'item_id': 99461,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'potatoes',
#   'item_id': 89599,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'tomatoes',
#   'item_id': 75330,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'onions',
#   'item_id': 91724,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'carrots',
#   'item_id': 22481,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'lettuce',
#   'item_id': 40631,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'broccoli',
#   'item_id': 48349,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'peppers',
#   'item_id': 26725,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'celery',
#   'item_id': 49761,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'garlic',
#   'item_id': 67679,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetables',
#   'item': 'cucumbers',
#   'item_id': 53219,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Canned Goods',
#   'item': 'olives',
#   'item_id': 63588,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Canned Goods',
#   'item': 'soup',
#   'item_id': 91321,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Canned Goods',
#   'item': 'canned tuna',
#   'item_id': 92853,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Canned Goods',
#   'item': 'veggies',
#   'item_id': 55412,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Canned Goods',
#   'item': 'fruit',
#   'item_id': 43770,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Frozen Foods',
#   'item': 'fish',
#   'item_id': 37256,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Frozen Foods',
#   'item': 'ice cream',
#   'item_id': 38184,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Frozen Foods',
#   'item': 'pizza',
#   'item_id': 77761,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Frozen Foods',
#   'item': 'frozen potatoes',
#   'item_id': 29709,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Frozen Foods',
#   'item': 'ready meals',
#   'item_id': 70579,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Meat and Animal Products',
#   'item': 'chicken',
#   'item_id': 33590,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Meat and Animal Products',
#   'item': 'beef',
#   'item_id': 94762,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Meat and Animal Products',
#   'item': 'pork',
#   'item_id': 61592,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Meat and Animal Products',
#   'item': 'sausage',
#   'item_id': 35861,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Meat and Animal Products',
#   'item': 'eggs',
#   'item_id': 44613,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'veggie burgers',
#   'item_id': 22280,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'tofu',
#   'item_id': 95130,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'vegan fish',
#   'item_id': 84978,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'oat milk',
#   'item_id': 15399,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'vegan sausages',
#   'item_id': 82585,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Fish and shellfish',
#   'item': 'shrimp',
#   'item_id': 61764,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Fish and shellfish',
#   'item': 'crab',
#   'item_id': 92164,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Fish and shellfish',
#   'item': 'clams',
#   'item_id': 85539,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Fish and shellfish',
#   'item': 'tuna',
#   'item_id': 49575,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Fish and shellfish',
#   'item': 'salmon',
#   'item_id': 41258,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Fish and shellfish',
#   'item': 'tilapia',
#   'item_id': 35531,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Dairy',
#   'item': 'cheese',
#   'item_id': 67169,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Dairy',
#   'item': 'milk',
#   'item_id': 20907,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Dairy',
#   'item': 'yogurt',
#   'item_id': 87762,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Dairy',
#   'item': 'butter',
#   'item_id': 37032,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Deli',
#   'item': 'sliced cheese',
#   'item_id': 13557,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Deli',
#   'item': 'ham',
#   'item_id': 67720,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Deli',
#   'item': 'turkey',
#   'item_id': 33900,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Deli',
#   'item': 'salami',
#   'item_id': 16905,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'salt',
#   'item_id': 31814,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'sugar',
#   'item_id': 43831,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'pepper',
#   'item_id': 72867,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'oregano',
#   'item_id': 91194,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'cinnamon',
#   'item_id': 13983,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'ketchup',
#   'item_id': 26611,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'mayonnaise',
#   'item_id': 94769,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Condiments & Spices',
#   'item': 'mustard',
#   'item_id': 39739,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Sauces & Oils',
#   'item': 'olive oil',
#   'item_id': 97881,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Sauces & Oils',
#   'item': 'tomato sauce',
#   'item_id': 46457,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Sauces & Oils',
#   'item': 'hot sauce',
#   'item_id': 94318,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Sauces & Oils',
#   'item': 'soy sauce',
#   'item_id': 54082,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'chips',
#   'item_id': 74469,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'crackers',
#   'item_id': 24109,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'pretzels',
#   'item_id': 74712,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'popcorn',
#   'item_id': 14563,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'peanuts',
#   'item_id': 63732,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'nuts',
#   'item_id': 20537,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Snacks',
#   'item': 'candy',
#   'item_id': 71183,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'whole wheat',
#   'item_id': 43893,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'white',
#   'item_id': 39679,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'italian',
#   'item_id': 72139,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'sandwich',
#   'item_id': 33242,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'tortillas',
#   'item_id': 16948,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'pies',
#   'item_id': 45901,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'muffins',
#   'item_id': 95207,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'bagels',
#   'item_id': 73554,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Bread & Bakery',
#   'item': 'cookies',
#   'item_id': 84395,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'water',
#   'item_id': 39293,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'coffee',
#   'item_id': 93141,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'juice',
#   'item_id': 27122,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'soda',
#   'item_id': 69764,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'tea',
#   'item_id': 56913,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'beer',
#   'item_id': 78677,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Beverages',
#   'item': 'wine',
#   'item_id': 58272,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Pasta/Rice',
#   'item': 'spaghetti',
#   'item_id': 14783,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Pasta/Rice',
#   'item': 'macaroni',
#   'item_id': 11656,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Pasta/Rice',
#   'item': 'noodles',
#   'item_id': 41944,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Pasta/Rice',
#   'item': 'white rice',
#   'item_id': 44001,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Cereal',
#   'item': 'oats',
#   'item_id': 40982,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Cereal',
#   'item': 'rice',
#   'item_id': 99406,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Cereal',
#   'item': 'wheat',
#   'item_id': 23802,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Cereal',
#   'item': 'granola',
#   'item_id': 31738,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Baking',
#   'item': 'flour',
#   'item_id': 64349,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Baking',
#   'item': 'baking powder',
#   'item_id': 67786,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Baking',
#   'item': 'sprinkles',
#   'item_id': 86128,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'shampoo',
#   'item_id': 33964,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'conditioner',
#   'item_id': 52619,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'soap',
#   'item_id': 10981,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'deodorant',
#   'item_id': 58973,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'toothpaste',
#   'item_id': 16979,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'dental floss',
#   'item_id': 40634,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'shaving cream',
#   'item_id': 64313,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Personal Care',
#   'item': 'razor blades',
#   'item_id': 66995,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Health Care',
#   'item': 'band-aid',
#   'item_id': 89842,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Health Care',
#   'item': 'hydrogen peroxide',
#   'item_id': 53586,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Health Care',
#   'item': 'rubbing alcohol',
#   'item_id': 28805,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Health Care',
#   'item': 'pain reliever',
#   'item_id': 91276,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Health Care',
#   'item': 'antacids',
#   'item_id': 29034,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Paper & Wrap',
#   'item': 'toilet paper',
#   'item_id': 64849,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Paper & Wrap',
#   'item': 'paper towels',
#   'item_id': 92995,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Paper & Wrap',
#   'item': 'tissues',
#   'item_id': 66371,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Paper & Wrap',
#   'item': 'aluminum foil',
#   'item_id': 45492,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Paper & Wrap',
#   'item': 'zip bags',
#   'item_id': 29740,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'detergent',
#   'item_id': 38077,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'softener',
#   'item_id': 77534,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'bleach',
#   'item_id': 26682,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'dish soap',
#   'item_id': 21681,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'air freshener',
#   'item_id': 38562,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'gloves',
#   'item_id': 68264,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'sponge',
#   'item_id': 78815,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'trash bags',
#   'item_id': 15671,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Household Supplies',
#   'item': 'batteries',
#   'item_id': 43252,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Baby Items',
#   'item': 'baby food',
#   'item_id': 78264,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Baby Items',
#   'item': 'diapers',
#   'item_id': 64434,
#   'quantity': 1,
#   'store_id': 8040},
#  {'category': 'Baby Items',
#   'item': 'wet wipes',
#   'item_id': 10801,
#   'quantity': 4,
#   'store_id': 8040},
#  {'category': 'Baby Items',
#   'item': 'moisturizing lotion',
#   'item_id': 67851,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Other items',
#   'item': 'pet food',
#   'item_id': 55192,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Other items',
#   'item': 'flowers',
#   'item_id': 33171,
#   'quantity': 2,
#   'store_id': 8040},
#  {'category': 'Other items',
#   'item': 'tobacco',
#   'item_id': 99107,
#   'quantity': 3,
#   'store_id': 8040},
#  {'category': 'Fruits',
#   'item': 'bananas',
#   'item_id': 19917,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'apples',
#   'item_id': 83260,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'grapes',
#   'item_id': 78138,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'oranges',
#   'item_id': 39399,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'strawberries',
#   'item_id': 85617,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'avocados',
#   'item_id': 44717,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'peaches',
#   'item_id': 28815,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'pineapple',
#   'item_id': 53555,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'pears',
#   'item_id': 99461,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'potatoes',
#   'item_id': 89599,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'tomatoes',
#   'item_id': 75330,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'onions',
#   'item_id': 91724,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'carrots',
#   'item_id': 22481,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'lettuce',
#   'item_id': 40631,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'broccoli',
#   'item_id': 48349,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'peppers',
#   'item_id': 26725,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'celery',
#   'item_id': 49761,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'garlic',
#   'item_id': 67679,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetables',
#   'item': 'cucumbers',
#   'item_id': 53219,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Canned Goods',
#   'item': 'olives',
#   'item_id': 63588,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Canned Goods',
#   'item': 'soup',
#   'item_id': 91321,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Canned Goods',
#   'item': 'canned tuna',
#   'item_id': 92853,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Canned Goods',
#   'item': 'veggies',
#   'item_id': 55412,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Canned Goods',
#   'item': 'fruit',
#   'item_id': 43770,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Frozen Foods',
#   'item': 'fish',
#   'item_id': 37256,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Frozen Foods',
#   'item': 'ice cream',
#   'item_id': 38184,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Frozen Foods',
#   'item': 'pizza',
#   'item_id': 77761,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Frozen Foods',
#   'item': 'frozen potatoes',
#   'item_id': 29709,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Frozen Foods',
#   'item': 'ready meals',
#   'item_id': 70579,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Meat and Animal Products',
#   'item': 'chicken',
#   'item_id': 33590,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Meat and Animal Products',
#   'item': 'beef',
#   'item_id': 94762,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Meat and Animal Products',
#   'item': 'pork',
#   'item_id': 61592,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Meat and Animal Products',
#   'item': 'sausage',
#   'item_id': 35861,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Meat and Animal Products',
#   'item': 'eggs',
#   'item_id': 44613,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'veggie burgers',
#   'item_id': 22280,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'tofu',
#   'item_id': 95130,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'vegan fish',
#   'item_id': 84978,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'oat milk',
#   'item_id': 15399,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'vegan sausages',
#   'item_id': 82585,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fish and shellfish',
#   'item': 'shrimp',
#   'item_id': 61764,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Fish and shellfish',
#   'item': 'crab',
#   'item_id': 92164,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Fish and shellfish',
#   'item': 'clams',
#   'item_id': 85539,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fish and shellfish',
#   'item': 'tuna',
#   'item_id': 49575,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Fish and shellfish',
#   'item': 'salmon',
#   'item_id': 41258,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Fish and shellfish',
#   'item': 'tilapia',
#   'item_id': 35531,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Dairy',
#   'item': 'cheese',
#   'item_id': 67169,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Dairy',
#   'item': 'milk',
#   'item_id': 20907,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Dairy',
#   'item': 'yogurt',
#   'item_id': 87762,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Dairy',
#   'item': 'butter',
#   'item_id': 37032,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Deli',
#   'item': 'sliced cheese',
#   'item_id': 13557,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Deli',
#   'item': 'ham',
#   'item_id': 67720,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Deli',
#   'item': 'turkey',
#   'item_id': 33900,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Deli',
#   'item': 'salami',
#   'item_id': 16905,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'salt',
#   'item_id': 31814,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'sugar',
#   'item_id': 43831,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'pepper',
#   'item_id': 72867,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'oregano',
#   'item_id': 91194,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'cinnamon',
#   'item_id': 13983,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'ketchup',
#   'item_id': 26611,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'mayonnaise',
#   'item_id': 94769,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Condiments & Spices',
#   'item': 'mustard',
#   'item_id': 39739,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Sauces & Oils',
#   'item': 'olive oil',
#   'item_id': 97881,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Sauces & Oils',
#   'item': 'tomato sauce',
#   'item_id': 46457,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Sauces & Oils',
#   'item': 'hot sauce',
#   'item_id': 94318,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Sauces & Oils',
#   'item': 'soy sauce',
#   'item_id': 54082,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'chips',
#   'item_id': 74469,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'crackers',
#   'item_id': 24109,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'pretzels',
#   'item_id': 74712,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'popcorn',
#   'item_id': 14563,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'peanuts',
#   'item_id': 63732,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'nuts',
#   'item_id': 20537,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Snacks',
#   'item': 'candy',
#   'item_id': 71183,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'whole wheat',
#   'item_id': 43893,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'white',
#   'item_id': 39679,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'italian',
#   'item_id': 72139,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'sandwich',
#   'item_id': 33242,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'tortillas',
#   'item_id': 16948,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'pies',
#   'item_id': 45901,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'muffins',
#   'item_id': 95207,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'bagels',
#   'item_id': 73554,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Bread & Bakery',
#   'item': 'cookies',
#   'item_id': 84395,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'water',
#   'item_id': 39293,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'coffee',
#   'item_id': 93141,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'juice',
#   'item_id': 27122,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'soda',
#   'item_id': 69764,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'tea',
#   'item_id': 56913,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'beer',
#   'item_id': 78677,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Beverages',
#   'item': 'wine',
#   'item_id': 58272,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Pasta/Rice',
#   'item': 'spaghetti',
#   'item_id': 14783,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Pasta/Rice',
#   'item': 'macaroni',
#   'item_id': 11656,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Pasta/Rice',
#   'item': 'noodles',
#   'item_id': 41944,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Pasta/Rice',
#   'item': 'white rice',
#   'item_id': 44001,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Cereal',
#   'item': 'oats',
#   'item_id': 40982,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Cereal',
#   'item': 'rice',
#   'item_id': 99406,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Cereal',
#   'item': 'wheat',
#   'item_id': 23802,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Cereal',
#   'item': 'granola',
#   'item_id': 31738,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Baking',
#   'item': 'flour',
#   'item_id': 64349,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Baking',
#   'item': 'baking powder',
#   'item_id': 67786,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Baking',
#   'item': 'sprinkles',
#   'item_id': 86128,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'shampoo',
#   'item_id': 33964,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'conditioner',
#   'item_id': 52619,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'soap',
#   'item_id': 10981,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'deodorant',
#   'item_id': 58973,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'toothpaste',
#   'item_id': 16979,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'dental floss',
#   'item_id': 40634,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'shaving cream',
#   'item_id': 64313,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Personal Care',
#   'item': 'razor blades',
#   'item_id': 66995,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Health Care',
#   'item': 'band-aid',
#   'item_id': 89842,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Health Care',
#   'item': 'hydrogen peroxide',
#   'item_id': 53586,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Health Care',
#   'item': 'rubbing alcohol',
#   'item_id': 28805,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Health Care',
#   'item': 'pain reliever',
#   'item_id': 91276,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Health Care',
#   'item': 'antacids',
#   'item_id': 29034,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Paper & Wrap',
#   'item': 'toilet paper',
#   'item_id': 64849,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Paper & Wrap',
#   'item': 'paper towels',
#   'item_id': 92995,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Paper & Wrap',
#   'item': 'tissues',
#   'item_id': 66371,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Paper & Wrap',
#   'item': 'aluminum foil',
#   'item_id': 45492,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Paper & Wrap',
#   'item': 'zip bags',
#   'item_id': 29740,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'detergent',
#   'item_id': 38077,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'softener',
#   'item_id': 77534,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'bleach',
#   'item_id': 26682,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'dish soap',
#   'item_id': 21681,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'air freshener',
#   'item_id': 38562,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'gloves',
#   'item_id': 68264,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'sponge',
#   'item_id': 78815,
#   'quantity': 4,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'trash bags',
#   'item_id': 15671,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Household Supplies',
#   'item': 'batteries',
#   'item_id': 43252,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Baby Items',
#   'item': 'baby food',
#   'item_id': 78264,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Baby Items',
#   'item': 'diapers',
#   'item_id': 64434,
#   'quantity': 2,
#   'store_id': 4936},
#  {'category': 'Baby Items',
#   'item': 'wet wipes',
#   'item_id': 10801,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Baby Items',
#   'item': 'moisturizing lotion',
#   'item_id': 67851,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Other items',
#   'item': 'pet food',
#   'item_id': 55192,
#   'quantity': 3,
#   'store_id': 4936},
#  {'category': 'Other items',
#   'item': 'flowers',
#   'item_id': 33171,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Other items',
#   'item': 'tobacco',
#   'item_id': 99107,
#   'quantity': 1,
#   'store_id': 4936},
#  {'category': 'Fruits',
#   'item': 'bananas',
#   'item_id': 19917,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'apples',
#   'item_id': 83260,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'grapes',
#   'item_id': 78138,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'oranges',
#   'item_id': 39399,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'strawberries',
#   'item_id': 85617,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'avocados',
#   'item_id': 44717,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'peaches',
#   'item_id': 28815,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'pineapple',
#   'item_id': 53555,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Fruits',
#   'item': 'pears',
#   'item_id': 99461,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'potatoes',
#   'item_id': 89599,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'tomatoes',
#   'item_id': 75330,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'onions',
#   'item_id': 91724,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'carrots',
#   'item_id': 22481,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'lettuce',
#   'item_id': 40631,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'broccoli',
#   'item_id': 48349,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'peppers',
#   'item_id': 26725,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'celery',
#   'item_id': 49761,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'garlic',
#   'item_id': 67679,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Vegetables',
#   'item': 'cucumbers',
#   'item_id': 53219,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Canned Goods',
#   'item': 'olives',
#   'item_id': 63588,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Canned Goods',
#   'item': 'soup',
#   'item_id': 91321,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Canned Goods',
#   'item': 'canned tuna',
#   'item_id': 92853,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Canned Goods',
#   'item': 'veggies',
#   'item_id': 55412,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Canned Goods',
#   'item': 'fruit',
#   'item_id': 43770,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Frozen Foods',
#   'item': 'fish',
#   'item_id': 37256,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Frozen Foods',
#   'item': 'ice cream',
#   'item_id': 38184,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Frozen Foods',
#   'item': 'pizza',
#   'item_id': 77761,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Frozen Foods',
#   'item': 'frozen potatoes',
#   'item_id': 29709,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Frozen Foods',
#   'item': 'ready meals',
#   'item_id': 70579,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Meat and Animal Products',
#   'item': 'chicken',
#   'item_id': 33590,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Meat and Animal Products',
#   'item': 'beef',
#   'item_id': 94762,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Meat and Animal Products',
#   'item': 'pork',
#   'item_id': 61592,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Meat and Animal Products',
#   'item': 'sausage',
#   'item_id': 35861,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Meat and Animal Products',
#   'item': 'eggs',
#   'item_id': 44613,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'veggie burgers',
#   'item_id': 22280,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'tofu',
#   'item_id': 95130,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'vegan fish',
#   'item_id': 84978,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'oat milk',
#   'item_id': 15399,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Vegetarian and Vegan Alternatives',
#   'item': 'vegan sausages',
#   'item_id': 82585,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Fish and shellfish',
#   'item': 'shrimp',
#   'item_id': 61764,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Fish and shellfish',
#   'item': 'crab',
#   'item_id': 92164,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Fish and shellfish',
#   'item': 'clams',
#   'item_id': 85539,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Fish and shellfish',
#   'item': 'tuna',
#   'item_id': 49575,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Fish and shellfish',
#   'item': 'salmon',
#   'item_id': 41258,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Fish and shellfish',
#   'item': 'tilapia',
#   'item_id': 35531,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Dairy',
#   'item': 'cheese',
#   'item_id': 67169,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Dairy',
#   'item': 'milk',
#   'item_id': 20907,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Dairy',
#   'item': 'yogurt',
#   'item_id': 87762,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Dairy',
#   'item': 'butter',
#   'item_id': 37032,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Deli',
#   'item': 'sliced cheese',
#   'item_id': 13557,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Deli',
#   'item': 'ham',
#   'item_id': 67720,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Deli',
#   'item': 'turkey',
#   'item_id': 33900,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Deli',
#   'item': 'salami',
#   'item_id': 16905,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'salt',
#   'item_id': 31814,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'sugar',
#   'item_id': 43831,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'pepper',
#   'item_id': 72867,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'oregano',
#   'item_id': 91194,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'cinnamon',
#   'item_id': 13983,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'ketchup',
#   'item_id': 26611,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'mayonnaise',
#   'item_id': 94769,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Condiments & Spices',
#   'item': 'mustard',
#   'item_id': 39739,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Sauces & Oils',
#   'item': 'olive oil',
#   'item_id': 97881,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Sauces & Oils',
#   'item': 'tomato sauce',
#   'item_id': 46457,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Sauces & Oils',
#   'item': 'hot sauce',
#   'item_id': 94318,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Sauces & Oils',
#   'item': 'soy sauce',
#   'item_id': 54082,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'chips',
#   'item_id': 74469,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'crackers',
#   'item_id': 24109,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'pretzels',
#   'item_id': 74712,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'popcorn',
#   'item_id': 14563,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'peanuts',
#   'item_id': 63732,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'nuts',
#   'item_id': 20537,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Snacks',
#   'item': 'candy',
#   'item_id': 71183,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'whole wheat',
#   'item_id': 43893,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'white',
#   'item_id': 39679,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'italian',
#   'item_id': 72139,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'sandwich',
#   'item_id': 33242,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'tortillas',
#   'item_id': 16948,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'pies',
#   'item_id': 45901,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'muffins',
#   'item_id': 95207,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'bagels',
#   'item_id': 73554,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Bread & Bakery',
#   'item': 'cookies',
#   'item_id': 84395,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'water',
#   'item_id': 39293,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'coffee',
#   'item_id': 93141,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'juice',
#   'item_id': 27122,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'soda',
#   'item_id': 69764,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'tea',
#   'item_id': 56913,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'beer',
#   'item_id': 78677,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Beverages',
#   'item': 'wine',
#   'item_id': 58272,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Pasta/Rice',
#   'item': 'spaghetti',
#   'item_id': 14783,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Pasta/Rice',
#   'item': 'macaroni',
#   'item_id': 11656,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Pasta/Rice',
#   'item': 'noodles',
#   'item_id': 41944,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Pasta/Rice',
#   'item': 'white rice',
#   'item_id': 44001,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Cereal',
#   'item': 'oats',
#   'item_id': 40982,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Cereal',
#   'item': 'rice',
#   'item_id': 99406,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Cereal',
#   'item': 'wheat',
#   'item_id': 23802,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Cereal',
#   'item': 'granola',
#   'item_id': 31738,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Baking',
#   'item': 'flour',
#   'item_id': 64349,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Baking',
#   'item': 'baking powder',
#   'item_id': 67786,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Baking',
#   'item': 'sprinkles',
#   'item_id': 86128,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'shampoo',
#   'item_id': 33964,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'conditioner',
#   'item_id': 52619,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'soap',
#   'item_id': 10981,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'deodorant',
#   'item_id': 58973,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'toothpaste',
#   'item_id': 16979,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'dental floss',
#   'item_id': 40634,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'shaving cream',
#   'item_id': 64313,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Personal Care',
#   'item': 'razor blades',
#   'item_id': 66995,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Health Care',
#   'item': 'band-aid',
#   'item_id': 89842,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Health Care',
#   'item': 'hydrogen peroxide',
#   'item_id': 53586,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Health Care',
#   'item': 'rubbing alcohol',
#   'item_id': 28805,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Health Care',
#   'item': 'pain reliever',
#   'item_id': 91276,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Health Care',
#   'item': 'antacids',
#   'item_id': 29034,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Paper & Wrap',
#   'item': 'toilet paper',
#   'item_id': 64849,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Paper & Wrap',
#   'item': 'paper towels',
#   'item_id': 92995,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Paper & Wrap',
#   'item': 'tissues',
#   'item_id': 66371,
#   'quantity': 4,
#   'store_id': 9916},
#  {'category': 'Paper & Wrap',
#   'item': 'aluminum foil',
#   'item_id': 45492,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Paper & Wrap',
#   'item': 'zip bags',
#   'item_id': 29740,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'detergent',
#   'item_id': 38077,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'softener',
#   'item_id': 77534,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'bleach',
#   'item_id': 26682,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'dish soap',
#   'item_id': 21681,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'air freshener',
#   'item_id': 38562,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'gloves',
#   'item_id': 68264,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'sponge',
#   'item_id': 78815,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'trash bags',
#   'item_id': 15671,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Household Supplies',
#   'item': 'batteries',
#   'item_id': 43252,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Baby Items',
#   'item': 'baby food',
#   'item_id': 78264,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Baby Items',
#   'item': 'diapers',
#   'item_id': 64434,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Baby Items',
#   'item': 'wet wipes',
#   'item_id': 10801,
#   'quantity': 1,
#   'store_id': 9916},
#  {'category': 'Baby Items',
#   'item': 'moisturizing lotion',
#   'item_id': 67851,
#   'quantity': 3,
#   'store_id': 9916},
#  {'category': 'Other items',
#   'item': 'pet food',
#   'item_id': 55192,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Other items',
#   'item': 'flowers',
#   'item_id': 33171,
#   'quantity': 2,
#   'store_id': 9916},
#  {'category': 'Other items',
#   'item': 'tobacco',
#   'item_id': 99107,
#   'quantity': 1,
#   'store_id': 9916}]

# %%
with open('data/inventory.json', 'w', encoding='utf-8') as f:
    json.dump(INVENTORY_LIST, f, indent=4)

# %% [markdown]
# ## testing logic for federated exercise
#
# = Additional challenge:
#
# - Think through how you might actually incorporate testing in a federated enviornment as a team exercise!

# %%
import pandas as pd

total_demand_list = []

for userlist in LIST_DATASET:
    for location in userlist['store_location_preferences']:
        for item in userlist['list_items']:
            total_demand_list.append([location, item['item_id'], item['quantity'] * -1])

total_inventory_list = [[inventory_item['store_id'], 
                        inventory_item['item_id'], 
                        inventory_item['quantity']] for inventory_item in INVENTORY_LIST]

consolidated_demand = pd.DataFrame(total_demand_list + total_inventory_list,
                                  columns=['store_id', 'item_id', 'quantity'])

final_result = consolidated_demand.groupby(['store_id', 'item_id'], as_index=False)['quantity'].sum()

# %%
for line in final_result.to_numpy():
    print(line)
# Out:
# [ 4936 10801    -1]
# [ 4936 10981     1]
# [ 4936 11656    -1]
# [ 4936 13557    -2]
# [ 4936 13983     1]
# [ 4936 14563     4]
# [ 4936 14783    -2]
# [ 4936 15399     1]
# [ 4936 15671     3]
# [ 4936 16905    -2]
# [ 4936 16948     3]
# [ 4936 16979     2]
# [ 4936 19917    -1]
# [ 4936 20537     1]
# [ 4936 20907     2]
# [ 4936 21681     1]
# [ 4936 22280     0]
# [ 4936 22481     1]
# [ 4936 23802     1]
# [ 4936 24109     0]
# [ 4936 26611     2]
# [ 4936 26682     1]
# [ 4936 26725     0]
# [ 4936 27122     3]
# [ 4936 28805    -1]
# [ 4936 28815    -2]
# [ 4936 29034    -1]
# [ 4936 29709    -4]
# [ 4936 29740     1]
# [ 4936 31738    -3]
# [ 4936 31814     2]
# [ 4936 33171     0]
# [ 4936 33242     1]
# [ 4936 33590     1]
# [ 4936 33900     3]
# [ 4936 33964     1]
# [ 4936 35531     1]
# [ 4936 35861     2]
# [ 4936 37032     1]
# [ 4936 37256    -8]
# [ 4936 38077     2]
# [ 4936 38184     3]
# [ 4936 38562     1]
# [ 4936 39293     2]
# [ 4936 39399     0]
# [ 4936 39679     4]
# [ 4936 39739     1]
# [ 4936 40631    -4]
# [ 4936 40634     1]
# [ 4936 40982    -4]
# [ 4936 41258     0]
# [ 4936 41944     2]
# [ 4936 43252    -2]
# [ 4936 43770     0]
# [ 4936 43831    -1]
# [ 4936 43893    -4]
# [ 4936 44001    -2]
# [ 4936 44613     0]
# [ 4936 44717    -2]
# [ 4936 45492     4]
# [ 4936 45901     2]
# [ 4936 46457     1]
# [ 4936 48349     1]
# [ 4936 49575     0]
# [ 4936 49761     2]
# [ 4936 52619     3]
# [ 4936 53219     2]
# [ 4936 53555     3]
# [ 4936 53586     2]
# [ 4936 54082     2]
# [ 4936 55192     3]
# [ 4936 55412     1]
# [ 4936 56913     2]
# [ 4936 58272     1]
# [ 4936 58973     1]
# [ 4936 61592    -1]
# [ 4936 61764     2]
# [ 4936 63588     1]
# [ 4936 63732     0]
# [ 4936 64313     1]
# [ 4936 64349     2]
# [ 4936 64434     0]
# [ 4936 64849     3]
# [ 4936 66371     2]
# [ 4936 66995     3]
# [ 4936 67169     1]
# [ 4936 67679     1]
# [ 4936 67720     4]
# [ 4936 67786     3]
# [ 4936 67851    -2]
# [ 4936 68264     1]
# [ 4936 69764     3]
# [ 4936 70579     0]
# [ 4936 71183     1]
# [ 4936 72139    -1]
# [ 4936 72867     2]
# [ 4936 73554     1]
# [ 4936 74469     1]
# [ 4936 74712     1]
# [ 4936 75330     1]
# [ 4936 77534     3]
# [ 4936 77761     2]
# [ 4936 78138     1]
# [ 4936 78264     1]
# [ 4936 78677     1]
# [ 4936 78815     4]
# [ 4936 82585     1]
# [ 4936 83260     1]
# [ 4936 84395     1]
# [ 4936 84978     3]
# [ 4936 85539     1]
# [ 4936 85617     2]
# [ 4936 86128     4]
# [ 4936 87762     2]
# [ 4936 89599     1]
# [ 4936 89842     1]
# [ 4936 91194     1]
# [ 4936 91276     2]
# [ 4936 91321     0]
# [ 4936 91724     2]
# [ 4936 92164     1]
# [ 4936 92853     2]
# [ 4936 92995     3]
# [ 4936 93141     2]
# [ 4936 94318     3]
# [ 4936 94762     2]
# [ 4936 94769     4]
# [ 4936 95130     1]
# [ 4936 95207     4]
# [ 4936 97881     2]
# [ 4936 99107     1]
# [ 4936 99406    -1]
# [ 4936 99461     1]
# [ 8040 10801     2]
# [ 8040 10981     2]
# [ 8040 11656    -2]
# [ 8040 13557     3]
# [ 8040 13983     1]
# [ 8040 14563     2]
# [ 8040 14783     0]
# [ 8040 15399     4]
# [ 8040 15671     3]
# [ 8040 16905     1]
# [ 8040 16948     1]
# [ 8040 16979     2]
# [ 8040 19917    -1]
# [ 8040 20537     3]
# [ 8040 20907     2]
# [ 8040 21681     2]
# [ 8040 22280     1]
# [ 8040 22481     2]
# [ 8040 23802     2]
# [ 8040 24109     4]
# [ 8040 26611     1]
# [ 8040 26682     2]
# [ 8040 26725     1]
# [ 8040 27122     1]
# [ 8040 28805    -1]
# [ 8040 28815     1]
# [ 8040 29034     4]
# [ 8040 29709     0]
# [ 8040 29740     3]
# [ 8040 31738     1]
# [ 8040 31814     3]
# [ 8040 33171     1]
# [ 8040 33242     1]
# [ 8040 33590     1]
# [ 8040 33900     2]
# [ 8040 33964     4]
# [ 8040 35531    -2]
# [ 8040 35861     1]
# [ 8040 37032     2]
# [ 8040 37256    -3]
# [ 8040 38077     1]
# [ 8040 38184     3]
# [ 8040 38562     3]
# [ 8040 39293     1]
# [ 8040 39399     1]
# [ 8040 39679     3]
# [ 8040 39739     3]
# [ 8040 40631     0]
# [ 8040 40634     4]
# [ 8040 40982    -2]
# [ 8040 41258     0]
# [ 8040 41944     2]
# [ 8040 43252     0]
# [ 8040 43770     1]
# [ 8040 43831    -3]
# [ 8040 43893    -3]
# [ 8040 44001    -1]
# [ 8040 44613     1]
# [ 8040 44717     2]
# [ 8040 45492     2]
# [ 8040 45901     1]
# [ 8040 46457     3]
# [ 8040 48349     3]
# [ 8040 49575     1]
# [ 8040 49761     2]
# [ 8040 52619     1]
# [ 8040 53219     1]
# [ 8040 53555     1]
# [ 8040 53586     2]
# [ 8040 54082     2]
# [ 8040 55192     2]
# [ 8040 55412     2]
# [ 8040 56913     1]
# [ 8040 58272     1]
# [ 8040 58973     0]
# [ 8040 61592     2]
# [ 8040 61764     1]
# [ 8040 63588     1]
# [ 8040 63732    -1]
# [ 8040 64313     0]
# [ 8040 64349     2]
# [ 8040 64434     1]
# [ 8040 64849     2]
# [ 8040 66371     1]
# [ 8040 66995     2]
# [ 8040 67169     2]
# [ 8040 67679     1]
# [ 8040 67720     4]
# [ 8040 67786     2]
# [ 8040 67851     2]
# [ 8040 68264     2]
# [ 8040 69764     2]
# [ 8040 70579     1]
# [ 8040 71183     1]
# [ 8040 72139     1]
# [ 8040 72867     2]
# [ 8040 73554     2]
# [ 8040 74469     1]
# [ 8040 74712     3]
# [ 8040 75330     4]
# [ 8040 77534     2]
# [ 8040 77761     1]
# [ 8040 78138     2]
# [ 8040 78264     3]
# [ 8040 78677     2]
# [ 8040 78815     3]
# [ 8040 82585     3]
# [ 8040 83260     2]
# [ 8040 84395     4]
# [ 8040 84978     1]
# [ 8040 85539     3]
# [ 8040 85617     4]
# [ 8040 86128     4]
# [ 8040 87762     2]
# [ 8040 89599     0]
# [ 8040 89842     1]
# [ 8040 91194     2]
# [ 8040 91276     1]
# [ 8040 91321     1]
# [ 8040 91724     1]
# [ 8040 92164    -2]
# [ 8040 92853     3]
# [ 8040 92995     3]
# [ 8040 93141     1]
# [ 8040 94318     2]
# [ 8040 94762     2]
# [ 8040 94769     2]
# [ 8040 95130     1]
# [ 8040 95207     4]
# [ 8040 97881     2]
# [ 8040 99107     3]
# [ 8040 99406     0]
# [ 8040 99461     3]
# [ 9916 10801     1]
# [ 9916 10981     1]
# [ 9916 11656     2]
# [ 9916 13557    -1]
# [ 9916 13983     2]
# [ 9916 14563     1]
# [ 9916 14783     3]
# [ 9916 15399     2]
# [ 9916 15671     1]
# [ 9916 16905    -1]
# [ 9916 16948     1]
# [ 9916 16979     3]
# [ 9916 19917    -2]
# [ 9916 20537     3]
# [ 9916 20907     3]
# [ 9916 21681     3]
# [ 9916 22280     1]
# [ 9916 22481     2]
# [ 9916 23802     2]
# [ 9916 24109    -1]
# [ 9916 26611     3]
# [ 9916 26682     2]
# [ 9916 26725     1]
# [ 9916 27122     3]
# [ 9916 28805     1]
# [ 9916 28815     0]
# [ 9916 29034     0]
# [ 9916 29709    -1]
# [ 9916 29740     3]
# [ 9916 31738     1]
# [ 9916 31814     3]
# [ 9916 33171     2]
# [ 9916 33242     1]
# [ 9916 33590     3]
# [ 9916 33900     3]
# [ 9916 33964     1]
# [ 9916 35531     3]
# [ 9916 35861     3]
# [ 9916 37032     1]
# [ 9916 37256    -3]
# [ 9916 38077     1]
# [ 9916 38184     1]
# [ 9916 38562     2]
# [ 9916 39293     1]
# [ 9916 39399     0]
# [ 9916 39679     4]
# [ 9916 39739     1]
# [ 9916 40631     0]
# [ 9916 40634     3]
# [ 9916 40982    -1]
# [ 9916 41258     2]
# [ 9916 41944     3]
# [ 9916 43252     1]
# [ 9916 43770    -1]
# [ 9916 43831     1]
# [ 9916 43893     0]
# [ 9916 44001     2]
# [ 9916 44613    -2]
# [ 9916 44717     0]
# [ 9916 45492     3]
# [ 9916 45901     2]
# [ 9916 46457     0]
# [ 9916 48349     3]
# [ 9916 49575     2]
# [ 9916 49761     2]
# [ 9916 52619     4]
# [ 9916 53219     3]
# [ 9916 53555     3]
# [ 9916 53586     1]
# [ 9916 54082     2]
# [ 9916 55192     2]
# [ 9916 55412     3]
# [ 9916 56913     2]
# [ 9916 58272     2]
# [ 9916 58973     2]
# [ 9916 61592    -3]
# [ 9916 61764     2]
# [ 9916 63588     1]
# [ 9916 63732     1]
# [ 9916 64313     4]
# [ 9916 64349     1]
# [ 9916 64434     0]
# [ 9916 64849     2]
# [ 9916 66371     4]
# [ 9916 66995     2]
# [ 9916 67169     2]
# [ 9916 67679     1]
# [ 9916 67720     2]
# [ 9916 67786     1]
# [ 9916 67851    -2]
# [ 9916 68264     1]
# [ 9916 69764     2]
# [ 9916 70579     3]
# [ 9916 71183     2]
# [ 9916 72139    -1]
# [ 9916 72867     1]
# [ 9916 73554     1]
# [ 9916 74469     3]
# [ 9916 74712     3]
# [ 9916 75330     1]
# [ 9916 77534     1]
# [ 9916 77761     2]
# [ 9916 78138     3]
# [ 9916 78264     1]
# [ 9916 78677     2]
# [ 9916 78815     2]
# [ 9916 82585     1]
# [ 9916 83260     4]
# [ 9916 84395     3]
# [ 9916 84978     1]
# [ 9916 85539     1]
# [ 9916 85617     3]
# [ 9916 86128     3]
# [ 9916 87762     2]
# [ 9916 89599     2]
# [ 9916 89842     4]
# [ 9916 91194     2]
# [ 9916 91276     4]
# [ 9916 91321     3]
# [ 9916 91724     3]
# [ 9916 92164     1]
# [ 9916 92853     2]
# [ 9916 92995     1]
# [ 9916 93141     2]
# [ 9916 94318     3]
# [ 9916 94762     2]
# [ 9916 94769     2]
# [ 9916 95130     3]
# [ 9916 95207     3]
# [ 9916 97881     2]
# [ 9916 99107     1]
# [ 9916 99406     2]
# [ 9916 99461     2]
